# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-2a2c46c5a02b> in <module>()
# ----> 1 df['Date'] = pd.to_datetime(df['Date'])
# ...

# %%
def my_agg(x):
    names = {'SettlementPointPrice': x['SettlementPointPrice'].iloc[-1]}
    return pd.Series(names, index=['Date', 'SettlementPointPrice'])

# %%
df.resample('1H').agg(my_agg)
# Out:
#                       Date  SettlementPointPrice
# Date
# 2010-12-01 01:00:00  25.08                 22.17
# 2010-12-01 02:00:00  21.96                 20.99
# 2010-12-01 03:00:00  21.25                 21.26
# 2010-12-01 04:00:00  21.76                 23.25
# 2010-12-01 05:00:00  24.16                 24.49
# 2010-12-01 06:00:00  24.56                 27.79
# 2010-12-01 07:00:00  29.12                 44.42
# 2010-12-01 08:00:00  34.21                 28.41
# 2010-12-01 09:00:00  27.91                 27.09
# 2010-12-01 10:00:00  27.24                 26.64
# 2010-12-01 11:00:00  26.54                 25.43
# 2010-12-01 12:00:00  23.52                 22.41
# 2010-12-01 13:00:00  22.36                 21.40
# 2010-12-01 14:00:00  21.49                 20.76
# 2010-12-01 15:00:00  20.95                 21.27
# 2010-12-01 16:00:00  20.36                 19.41
# 2010-12-01 17:00:00  19.40                 21.06
# 2010-12-01 18:00:00  21.80                 27.63
# ...

# %%
a.columns
# Out:
# MultiIndex(levels=[['SettlementPointPrice', 'Date'], ['SettlementPointPrice']],
#            labels=[[0, 1], [0, 0]])

# %%
df.resample('1H').agg({'Date': lambda x: x.iloc[0], 'SettlementPointPrice': lambda x: x.iloc[-1]})
