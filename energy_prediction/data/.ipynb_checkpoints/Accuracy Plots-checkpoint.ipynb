# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('HB_HOUSTON.csv')

# %%
dfTrain = df[:int(df.shape[0] * 0.8)]
dfTest = df[int(df.shape[0] * 0.8):]

# %%
def calculate_accuracy(df):
    df['datetime'] = pd.to_datetime(pd.to_datetime(df['date']) + df['hour'].astype('timedelta64[h]'))
    
    y = (df['price'].pct_change() > 0).astype(int)
    AL = (df['predicted_price'].pct_change() > 0).astype(int)
    
    assert(y.shape[0] == AL.shape[0])
    
    total = y.shape[0]
    TP = np.sum(np.logical_and(AL==1, y==1))
    TN = np.sum(np.logical_and(AL==0, y==0))

    FP = np.sum(np.logical_and(AL==1, y==0))
    FN = np.sum(np.logical_and(AL==0, y==1))

    P = TP / (TP + FP)
    R = TP / (TP + TN)
    F1 = (2 * P * R) / (P + R)

    acc = np.sum(AL == y)/total


    print("\nAccuracy: {} \n".format(acc))
    print("True Positive: {} \nTrue Negative: {}\nFalse Positive: {} \nFalse Negative: {}\n".format(TP, TN, FP, FN))
    print("Precision: {} \nRecall: {} \nF1 Score: {}\n".format(P, R, F1))   
    
    return y, AL, df['datetime']

# %%
y, AL, date = calculate_accuracy(dfTrain)
# Out:
# Accuracy: 0.875858214912981
#
# True Positive: 10510
# True Negative: 11432
# False Positive: 1702
# False Negative: 1408
#
# Precision: 0.8606288896167704
# Recall: 0.47899006471606964
# F1 Score: 0.6154476781636119

# %%
df
# Out:
#               hub        date  year  month  day  hour    price  \
# 0      HB_HOUSTON  2015-01-01  2015      1    1   1.0  22.4675
# 1      HB_HOUSTON  2015-01-01  2015      1    1   2.0  22.3050
# 2      HB_HOUSTON  2015-01-01  2015      1    1   3.0  22.2025
# 3      HB_HOUSTON  2015-01-01  2015      1    1   4.0  22.1275
# 4      HB_HOUSTON  2015-01-01  2015      1    1   5.0  22.1550
# 5      HB_HOUSTON  2015-01-01  2015      1    1   6.0  22.6100
# 6      HB_HOUSTON  2015-01-01  2015      1    1   7.0  23.3800
# 7      HB_HOUSTON  2015-01-01  2015      1    1   8.0  23.7775
# 8      HB_HOUSTON  2015-01-01  2015      1    1   9.0  24.4600
# 9      HB_HOUSTON  2015-01-01  2015      1    1  10.0  26.9925
# 10     HB_HOUSTON  2015-01-01  2015      1    1  11.0  27.9600
# 11     HB_HOUSTON  2015-01-01  2015      1    1  12.0  28.4250
# 12     HB_HOUSTON  2015-01-01  2015      1    1  13.0  27.4900
# 13     HB_HOUSTON  2015-01-01  2015      1    1  14.0  26.1950
# 14     HB_HOUSTON  2015-01-01  2015      1    1  15.0  24.8600
# 15     HB_HOUSTON  2015-01-01  2015      1    1  16.0  24.6225
# 16     HB_HOUSTON  2015-01-01  2015      1    1  17.0  25.5325
# 17     HB_HOUSTON  2015-01-01  2015      1    1  18.0  29.3075
# 18     HB_HOUSTON  2015-01-01  2015      1    1  19.0  28.6050
# 19     HB_HOUSTON  2015-01-01  2015      1    1  20.0  27.5700
# 20     HB_HOUSTON  2015-01-01  2015      1    1  21.0  27.4525
